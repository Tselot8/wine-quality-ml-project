# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("../data/winequality-red.csv", sep=';')

# Quality distribution
plt.figure(figsize=(8,5))
sns.countplot(x='quality', data=data)
plt.title("Distribution of Wine Quality")
plt.show()

# Correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# ### Objective
# This notebook focuses on exploring the dataset visually to identify patterns, distributions, correlations, and potential issues such as class imbalance.
#
# ### Key Tasks Performed
# - Visualized the distribution of wine quality scores
# - Analyzed feature correlations using a heatmap
#
# ### Findings
# - Wine quality scores are imbalanced, with most wines rated between 5 and 6.
# - Certain features such as alcohol and sulphates show strong correlations with quality.
#
# ### Relevance to Project Requirements
# This notebook fulfills the **Exploratory Data Analysis (EDA)** requirement and provides justification for later preprocessing and modeling decisions.
